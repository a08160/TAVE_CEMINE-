# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time

# 크롬 드라이버 경로 설정
driver = webdriver.Chrome()

# 첫 페이지 URL
url = "https://www.adidas.co.kr/women-originals-shoes"

# 웹 페이지 열기
driver.get(url)

# 페이지가 완전히 로드될 때까지 기다리기
time.sleep(2)

# # # driver.execute_script("window.scrollTo(0, 12000);") 
driver.find_element(By.XPATH, '//*[@id="glass-gdpr-default-consent-accept-button"]/span[1]').click( )
# time.sleep(2)
# driver.find_element(By.XPATH, '//*[@id="product-search-results"]/div[2]/div[3]/div/div[2]/div/div/div[49]/div[2]/div').click( )
# time.sleep(2)

# 요소들을 담을 리스트
elements = []

# XPath 패턴을 따라 요소들을 찾기 
for i in range(1, 48):
    xpath = f'//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[1]/div/div[{i}]/div/div/div/div/div/div/div[1]/a[2]/div/div/div'
    try:      
        element = driver.find_element(By.XPATH, xpath)
        elements.append(element.text)
    except Exception as e:
        print(f"Element not found for div[{i}]: {e}")

driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[2]/div/div/div/div[4]/a/span').click( )
time.sleep(4)

for i in range(1, 48):
    xpath = f'//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[1]/div/div[{i}]/div/div/div/div/div/div/div[1]/a[2]/div/div/div'
    try:      
        element = driver.find_element(By.XPATH, xpath)
        elements.append(element.text)
    except Exception as e:
        print(f"Element not found for div[{i}]: {e}")

driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[2]/div/div/div/div[4]/a/span').click( )
time.sleep(4)

for i in range(1, 48):
    xpath = f'//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[1]/div/div[{i}]/div/div/div/div/div/div/div[1]/a[2]/div/div/div'
    try:      
        element = driver.find_element(By.XPATH, xpath)
        elements.append(element.text)
    except Exception as e:
        print(f"Element not found for div[{i}]: {e}")

driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[2]/div/div/div/div[4]/a/span').click( )
time.sleep(4)

for i in range(1, 48):
    xpath = f'//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[1]/div/div[{i}]/div/div/div/div/div/div/div[1]/a[2]/div/div/div'
    try:      
        element = driver.find_element(By.XPATH, xpath)
        elements.append(element.text)
    except Exception as e:
        print(f"Element not found for div[{i}]: {e}")

driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[2]/div/div/div/div[4]/a/span').click( )
time.sleep(4)

for i in range(1, 48):
    xpath = f'//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[1]/div/div[{i}]/div/div/div/div/div/div/div[1]/a[2]/div/div/div'
    try:      
        element = driver.find_element(By.XPATH, xpath)
        elements.append(element.text)
    except Exception as e:
        print(f"Element not found for div[{i}]: {e}")

driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[2]/div/div/div/div[4]/a/span').click( )
time.sleep(4)

for i in range(1, 48):
    xpath = f'//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[1]/div/div[{i}]/div/div/div/div/div/div/div[1]/a[2]/div/div/div'
    try:      
        element = driver.find_element(By.XPATH, xpath)
        elements.append(element.text)
    except Exception as e:
        print(f"Element not found for div[{i}]: {e}")

driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[2]/div/div/div/div[4]/a/span').click( )
time.sleep(4)

for i in range(1, 48):
    xpath = f'//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[1]/div/div[{i}]/div/div/div/div/div/div/div[1]/a[2]/div/div/div'
    try:      
        element = driver.find_element(By.XPATH, xpath)
        elements.append(element.text)
    except Exception as e:
        print(f"Element not found for div[{i}]: {e}")

driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[2]/div/div/div/div[4]/a/span').click( )
time.sleep(4)

for i in range(1, 48):
    xpath = f'//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[1]/div/div[{i}]/div/div/div/div/div/div/div[1]/a[2]/div/div/div'
    try:      
        element = driver.find_element(By.XPATH, xpath)
        elements.append(element.text)
    except Exception as e:
        print(f"Element not found for div[{i}]: {e}")

driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[2]/div/div/div/div[4]/a/span').click( )
time.sleep(4)

for i in range(1, 48):
    xpath = f'//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[1]/div/div[{i}]/div/div/div/div/div/div/div[1]/a[2]/div/div/div'
    try:      
        element = driver.find_element(By.XPATH, xpath)
        elements.append(element.text)
    except Exception as e:
        print(f"Element not found for div[{i}]: {e}")

driver.find_element(By.XPATH, '//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[2]/div/div/div/div[4]/a/span').click( )
time.sleep(4)

for i in range(1, 48):
    xpath = f'//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[1]/div/div[{i}]/div/div/div/div/div/div/div[1]/a[2]/div/div/div'
    try:      
        element = driver.find_element(By.XPATH, xpath)
        elements.append(element.text)
    except Exception as e:
        print(f"Element not found for div[{i}]: {e}")



# 요소 내용 출력
for idx, content in enumerate(elements):
    print(f"Element {idx + 1}: {content}")

# 브라우저 닫기
driver.quit()

# elements 리스트를 DataFrame으로 변환
df = pd.DataFrame(elements, columns=["Price"])

print(element)
# Out:
# Element not found for div[27]: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="main-content"]/div/div[2]/div/div/div[2]/div[1]/div/div[27]/div/div/div/div/div/div/div[1]/a[2]/div/div/div"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF72035EEA2+31554]
# 	(No symbol) [0x00007FF7202D7ED9]
# 	(No symbol) [0x00007FF72019872A]
# 	(No symbol) [0x00007FF7201E8434]
# 	(No symbol) [0x00007FF7201E853C]
# 	(No symbol) [0x00007FF72022F6A7]
# 	(No symbol) [0x00007FF72020D06F]
# 	(No symbol) [0x00007FF72022C977]
# 	(No symbol) [0x00007FF72020CDD3]
# 	(No symbol) [0x00007FF7201DA33B]
# 	(No symbol) [0x00007FF7201DAED1]
# 	GetHandleVerifier [0x00007FF720668B1D+3217341]
# 	GetHandleVerifier [0x00007FF7206B5AE3+3532675]
# 	GetHandleVerifier [0x00007FF7206AB0E0+3489152]
# ...

# %%
df.to_csv("Adidas전체가격(여성_오리지널스).csv", index=False, encoding='utf-8-sig')
